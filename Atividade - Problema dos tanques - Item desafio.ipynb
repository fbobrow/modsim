# %% [markdown]
# # Insper - Modelagem e Simulação do Mundo Físico
#
# ## Atividade - Problema dos tanques

# %%
# Importa bibliotecas necessárias
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### A 2ª iteração do problema dos tanques
#
# ![Captura%20de%20Tela%202022-09-21%20a%CC%80s%2014.56.41.png](attachment:Captura%20de%20Tela%202022-09-21%20a%CC%80s%2014.56.41.png)

# %% [markdown]
# Vamos, agora, ver como a variação da vazão da bomba afeta a dinâmica do tanque 1.
# #### Para fazer isso, você precisará ler, antes, a leitura prévia da aula 10.

# %% [markdown]
# #### a) Alterações
#
# Consulte seu código da atividade do problema dos tanques e copie no espaço abaixo a definição da função $v(T_2, d_2, t)$. Em seguida, copie a função $b(T_1)$ e modifique-a de tal modo que a vazão da bomba $Q_b$, em vez de ser uma variável global, seja um parâmetro da função. Ou seja, a função $b(T_1)$ passará a ser $b(T_1, Q_b)$. Da mesma forma, copie também a função `modelo(x, t)`, alterando-a para também receber a vazão como parâmetro, ou seja, `modelo(x, t, Qb)`.
#
# **Observação:** não se esqueça de declarar os valores das constantes $d_1$ e $d_2$.

# %%
# SEU CÓDIGO DO ITEM A

# %% [markdown]
# #### b) Gráfico
#
# Agora implemente uma lista com os seguintes valores de vazão: $[6 \quad 7 \quad 8 \quad \ldots \quad 20  \quad 21 \quad 22]$. Em seguida, copie o código do item **2c** da atividade do problema dos tanques (aquele em que você cria a lista de tempo e executa o `odeint`). Adapte-o para que seja plotados os gráficos de $T_1(t)$ por $t$ para cada valor de vazão da lista anterior, todos em uma mesma figura.
#
# **Observação:** não se esqueça de declarar novamente as condições iniciais e a lista de tempo.

# %%
# SEU CÓDIGO DO ITEM B
